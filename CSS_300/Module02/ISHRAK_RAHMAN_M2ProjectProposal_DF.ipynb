# %% [markdown]
# # Module 2 - Project Proposal
# Ishrak Rahman

# %%
import pandas as pd
data = pd.read_csv("house_price_bd.csv")

# %%
data.sample(10)
# Out:
#                                                   Title  Bedrooms  Bathrooms  \
# 3291  Plot Of 5 Katha Is Up For Sale In Narayanganj,...       NaN        NaN
# 2118  All Set For Selling Purpose This 1485 Sq Ft Fl...       3.0        4.0
# 3265  In The Location Of Bproperty Village ,Rupganj ...       NaN        NaN
# 2001  In Halishahar Near Navy Hospital, A 110 Sq. Ft...       NaN        NaN
# 3100  A 1180 Sq Ft Flat Is Up For Sale In A Well Sec...       3.0        3.0
# 3244  Positioned At Thakur Para, 1350 Sq Ft Resident...       3.0        3.0
# 3778  800 Sq Ft Apartment Is Available For Sale In T...       2.0        1.0
# 2713  163 Square Feet Commercial Shop For Sale At Ju...       NaN        NaN
# 274            Modern 1150 Sq Ft Flat For Sale In Badda       3.0        3.0
# 2116  An Amazing Flat Is Ready For Sale At Nasirabad...       3.0        3.0
#
#      Floor_no Occupancy_status  Floor_area              City Price_in_taka  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3865 entries, 0 to 3864
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Title             3865 non-null   object
#  1   Bedrooms          2864 non-null   float64
#  2   Bathrooms         2864 non-null   float64
#  3   Floor_no          3181 non-null   object
#  4   Occupancy_status  3766 non-null   object
#  5   Floor_area        3766 non-null   float64
#  6   City              3865 non-null   object
#  7   Price_in_taka     3865 non-null   object
#  8   Location          3859 non-null   object
# dtypes: float64(3), object(6)
# memory usage: 271.9+ KB
